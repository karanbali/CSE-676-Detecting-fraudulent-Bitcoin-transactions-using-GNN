# %% [markdown]
# ### Mounting Googel Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Importing Dependencies

# %%
import os
# !pip install dgl-cu111 -f https://data.dgl.ai/wheels/repo.html

import numpy as np
import dgl
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import urllib.request
import pandas as pd
import dgl.data
import dgl
from dgl.data import DGLDataset
import torch
import os
import itertools
import dgl.nn as dglnn
from dgl.nn import GraphConv



from scipy.spatial import Delaunay
from sklearn.metrics import f1_score
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
# Out:
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Requirement already satisfied: dgl-cu111 in /usr/local/lib/python3.7/dist-packages (0.7.2)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.19.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (1.4.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from dgl-cu111) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl-cu111) (2.10)

# %% [markdown]
# ### Reding CSV files defining the classes, edges and node feaures respectively. More details can be found at: https://www.kaggle.com/ellipticco/elliptic-data-set
#
# NOTE: Please change the path of the CSV files according to your directory structure.

# %%
classes = pd.read_csv('/content/gdrive/MyDrive/Fall_21/BC_DL/elliptic_bitcoin_dataset/elliptic_txs_classes.csv')
edges = pd.read_csv('/content/gdrive/MyDrive/Fall_21/BC_DL/elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv')
features = pd.read_csv('/content/gdrive/MyDrive/Fall_21/BC_DL/elliptic_bitcoin_dataset/elliptic_txs_features.csv',header=None).set_index(0,verify_integrity=True)

# %% [markdown]
# ### Filtering entries with unknown classes.

# %%
classes_filtered = classes
classes_filtered = classes_filtered[classes_filtered['class'] != 'unknown']

# %% [markdown]
# ### Spliting features into 2 sections: i) all entries with 1st feature value below 35 would be used for training ii) all entries with 2nd feature value above 35 would be used for testing.

# %%
features_train = features[features[1]<35]
features_test = features[features[1]>=35]

# %% [markdown]
# ### Creating Training & testing dataset

# %%
train_x = []
train_y = []

for index, row in features_train.iterrows():
  
  if (len(classes_filtered.loc[classes_filtered['txId']==index]['class'].values) != 0):
    train_x.append(row.to_numpy())
    if int(classes_filtered.loc[classes_filtered['txId']==index]['class'].values) == 1:
      val = 1
    elif int(classes_filtered.loc[classes_filtered['txId']==index]['class'].values) == 2:
      val = 0

    train_y.append(val)

# %%
test_x = []
test_y = []

for index, row in features_test.iterrows():
  
  if (len(classes_filtered.loc[classes_filtered['txId']==index]['class'].values) != 0):
    test_x.append(row.to_numpy())
    if int(classes_filtered.loc[classes_filtered['txId']==index]['class'].values) == 1:
      val = 1
    elif int(classes_filtered.loc[classes_filtered['txId']==index]['class'].values) == 2:
      val = 0

    test_y.append(val)

# %% [markdown]
# ### Fitting a Random Forest Classifier

# %%
clf = RandomForestClassifier(n_estimators=50, max_features=50)
clf.fit(train_x, train_y)
pred_rf = clf.predict(test_x)
f1 = f1_score(pred_rf, test_y, average=None)
f1m = f1_score(pred_rf, test_y, average='micro')
print("Final F1 score:",(f1[0]+f1[1])/2)
print("Final MicroAvg F1 score:",f1[0])
# Out:
# Final F1 score: 0.8973295230329974
# Final MicroAvg F1 score: 0.9880577051686251

# %% [markdown]
# ### Fitting a Logistic Regression Classifier

# %%
clf = LogisticRegression().fit(train_x, train_y)
pred_lr = clf.predict(test_x)
f1 = f1_score(pred_lr, test_y, average=None)
f1m = f1_score(pred_rf, test_y, average='micro')
print("Final F1 score:",(f1[0]+f1[1])/2)
print("Final MicroAvg F1 score:",f1[0])
# Out:
# Final F1 score: 0.6755566167407704
# Final MicroAvg F1 score: 0.9374273858921162
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %% [markdown]
# ### Creating a pytorch Dataset and Dataloader for the given bitcoin dataset

# %%
class DSet(Dataset):
    def __init__(self, feat, label):
        self.labels = label 
        self.feat = feat 
       

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        
        x = self.feat[idx]
        y = self.labels[idx]
        
        return x, y

# %% [markdown]
# ### Creating Pytorch dataset and dataloaders

# %%
train_ds = DSet(train_x,train_y)
test_ds = DSet(test_x,test_y)
train_dataloader = DataLoader(train_ds, batch_size=1000, shuffle=True)
test_dataloader = DataLoader(test_ds, batch_size=1000, shuffle=True)

# %% [markdown]
# ### Defing a evaluation function for MLP

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0

    f1_micro = 0
    f1_net = 0
    cnt = 0
    with torch.no_grad():
        for X, y in dataloader:
            y = torch.unsqueeze(y,1)
            X, y = X.float(), y.float()
            pred = model(X)
            test_loss += loss_fn(pred, y).item()


            pred = pred.argmax(1)
            y = torch.squeeze(y,1)
            
          

            f1_m = f1_score(pred, y, average='micro')
            f1 = f1_score(pred, y, average=None)

            f1_micro += f1[0]
            f1_net += (f1[0]+f1[1])/2
            cnt += 1



    print("Final F1 score:",f1_net/cnt)
    print("Final MicroAvg F1 score:",f1_micro/cnt)

# %% [markdown]
# ### Define a simple MLP

# %%
class MLP(nn.Module):
   
    def __init__(self, n_inputs):
        super(MLP, self).__init__()
        self.layer1 = nn.Linear(n_inputs, 50)
        self.layer2 = nn.Linear(50, 1)
        self.activation = nn.Sigmoid()

    
    def forward(self, X):
        X = self.layer1(X)
        X = self.layer2(X)
        X = self.activation(X)
        return X

# %% [markdown]
# ### Train and Evaluate MLP

# %%
model = MLP(train_x[0].shape[0])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.BCELoss()

for epoch in range(200):

    for i, (x, y) in enumerate(train_dataloader):

      y = torch.unsqueeze(y,1)
      x = x.float()
      y = y.float()
      optimizer.zero_grad()

      yhat = model(x)
      loss = criterion(yhat, y)

      print("LOSS:", loss)

      loss.backward()
      optimizer.step()

test(test_dataloader, model, criterion)
# Out:
# Streaming output truncated to the last 5000 lines.
# LOSS: tensor(0.1278, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1501, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1304, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1593, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1307, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1090, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1300, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1426, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1321, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1388, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1295, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1495, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1196, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1178, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2097, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1247, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1410, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1358, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1159, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1046, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1438, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1444, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1290, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1523, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1336, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1329, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1332, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1755, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1334, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1064, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1180, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1229, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1303, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1100, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1598, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1273, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1199, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1121, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1186, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1162, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1300, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1302, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2592, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1224, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1210, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1462, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1285, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1069, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1225, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1433, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1209, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1334, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1711, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1506, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1290, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1112, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1145, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1425, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1305, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1277, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1310, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1324, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1068, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1346, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1549, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0999, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1285, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1227, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1374, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1469, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1142, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1221, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2251, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1210, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1134, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1106, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1313, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1258, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1256, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1214, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1159, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1364, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1412, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1197, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1199, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2358, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1356, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1104, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1362, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1270, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1221, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0956, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1753, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1494, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1280, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1202, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1188, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1199, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1151, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1312, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1388, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1236, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1159, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1378, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1083, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1215, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1327, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1446, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1405, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1095, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1361, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1317, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1491, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1347, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1254, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1426, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1274, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1131, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1464, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2023, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1435, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1470, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1229, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1258, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1332, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1248, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1135, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1043, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1126, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1276, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1043, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1115, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1215, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1222, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1298, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1123, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1321, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1349, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1089, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1160, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1032, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1537, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1000, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1239, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1690, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1341, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1170, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1044, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1338, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1149, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1349, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1453, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1190, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1400, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1359, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1288, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1272, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1166, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1274, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1107, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1099, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1302, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1232, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1953, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1028, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1667, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1356, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1235, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1229, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1088, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1283, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1133, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1274, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1166, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2405, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1313, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1246, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1151, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1183, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1324, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1348, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1231, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1663, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1132, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1336, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1236, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1274, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1322, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1142, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1261, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1313, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1243, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1142, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1362, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1045, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1029, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1180, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1424, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0983, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1030, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1165, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1019, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1142, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1015, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1451, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1248, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1527, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1088, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1083, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1403, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1229, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1584, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1111, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2079, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1324, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1538, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0954, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1050, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1346, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0984, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1236, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1801, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1120, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1242, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1264, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1247, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1584, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1183, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1052, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1265, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1079, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0979, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1090, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0994, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1179, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1262, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1030, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1515, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1705, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1440, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0933, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2327, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1374, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1053, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1161, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1314, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1240, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1243, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1392, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1214, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1185, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1215, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1415, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1146, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1072, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1038, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1099, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1659, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0947, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2258, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1255, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1197, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0896, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1287, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1176, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1141, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1307, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1186, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1269, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0899, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1167, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1335, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1193, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1159, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1293, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1143, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1331, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1073, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1052, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1747, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1530, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1190, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1409, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1169, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1317, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1287, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1226, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0974, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1323, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1217, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1158, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2439, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1089, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1123, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1173, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1186, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1074, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1055, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1021, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1304, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1586, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1518, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1221, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1146, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1132, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1524, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1065, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1056, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1153, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0992, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1330, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1290, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1004, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1019, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1196, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1238, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1231, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1416, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1351, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0969, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1242, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1627, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1159, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1404, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1299, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1087, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0985, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1316, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1038, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1231, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1070, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1041, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1233, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1339, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1198, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1272, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1167, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1109, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1312, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1005, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1437, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1091, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1048, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1161, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1320, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2009, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1238, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1224, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1011, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1336, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1052, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0961, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0947, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0931, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1202, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1161, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1227, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1332, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1297, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0931, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2253, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1470, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1449, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1648, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1200, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1195, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1113, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1314, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1154, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1093, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1283, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1212, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1012, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1301, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1048, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1186, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1262, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1188, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1451, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1175, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1301, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1284, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1143, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1189, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1078, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0915, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1264, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1065, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1124, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1063, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1096, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1308, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1011, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1074, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1071, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1049, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1209, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1399, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1243, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1288, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1160, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1269, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1126, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1639, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2056, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0959, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1151, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1284, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1342, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0994, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1074, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1031, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1245, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1342, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1417, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2213, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1084, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1134, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1406, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1246, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0985, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1029, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0954, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1035, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1269, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1346, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1041, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1201, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1381, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1001, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1144, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1311, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0922, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2092, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1074, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1215, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0934, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1520, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1058, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1868, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1392, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1133, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1511, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0999, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0988, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1218, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1021, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1089, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1120, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1365, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1260, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1065, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1630, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0884, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2026, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1029, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1012, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1208, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1173, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1271, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1050, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1263, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1562, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1306, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1063, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0946, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1080, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1314, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1027, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1340, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1047, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1126, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1224, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2102, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1530, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0852, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1117, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1134, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1076, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0877, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1099, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1200, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1255, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1377, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1386, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2467, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0993, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1098, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1146, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0877, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1190, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1181, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1055, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1242, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1005, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1278, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1058, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1135, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1317, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1107, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0963, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1426, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0958, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0945, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1066, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1148, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1085, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1362, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2027, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1264, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1155, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1043, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0892, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1274, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1076, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1223, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0963, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1190, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1468, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1243, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1066, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1109, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1209, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1123, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1100, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1317, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1149, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2131, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1063, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0973, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0978, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1423, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1037, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0876, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1205, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1157, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1005, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1338, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1347, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1146, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1054, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1070, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1279, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1149, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1161, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2099, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0992, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1086, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1192, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1345, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1407, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0974, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1083, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1995, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1312, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1096, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1243, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0934, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0904, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1073, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0862, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0991, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1658, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1174, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1471, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1271, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1064, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1106, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1365, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1195, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1287, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0796, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0961, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1017, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1186, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1024, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1066, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1282, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1329, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1142, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1026, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1915, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1092, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0970, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2117, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0845, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1463, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1186, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2154, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0935, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2150, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1525, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1113, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1103, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1059, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1089, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1345, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1192, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1298, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0911, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0988, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1304, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0848, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1014, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1039, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0798, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0978, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1050, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1079, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1333, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1097, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1321, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1149, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0842, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1097, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1642, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0913, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1345, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1089, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1185, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0999, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1270, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0894, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2172, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1159, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1095, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1072, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1129, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1227, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1173, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1030, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0887, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1237, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1005, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1193, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1237, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1408, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1346, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0841, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1077, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1081, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1037, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2040, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0930, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1062, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1010, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1126, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1547, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0943, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2173, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1107, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1907, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1172, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0986, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1170, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1184, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1025, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1333, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0965, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1319, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0869, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1296, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1157, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1017, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1198, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1099, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1150, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1005, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1189, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1328, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1204, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0988, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1219, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1048, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0868, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0980, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1412, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1034, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1065, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1077, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1191, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2090, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1016, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1088, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0899, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0945, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1232, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1012, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1113, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0959, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1239, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2249, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1063, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1095, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1130, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1363, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1248, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1124, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1292, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1057, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0986, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1013, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1202, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1102, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1026, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0967, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1096, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1182, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1246, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1015, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1029, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0880, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1245, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1131, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1079, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0973, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1158, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1132, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0971, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1282, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1237, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0902, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1962, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0968, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0973, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0902, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1340, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1176, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1158, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0916, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1015, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1070, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2202, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1109, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0961, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1564, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1002, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1202, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1063, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1013, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0885, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1265, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0903, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0865, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0979, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0951, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1029, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1334, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1103, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1010, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2169, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0932, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1172, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1147, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0932, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1224, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1076, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1019, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1176, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1122, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1059, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1339, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1075, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1217, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1109, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0941, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1110, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2605, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1358, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1293, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0868, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0959, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1311, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0939, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1093, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1448, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0990, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0989, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1092, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1079, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1128, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0948, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0830, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0925, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1149, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1079, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0865, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1078, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1315, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1995, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1217, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.2120, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0886, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1116, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0873, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1200, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1246, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1177, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0794, grad_fn=<BinaryCrossEntropyBackward0>)
# ...
# LOSS: tensor(0.0706, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0704, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0914, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0878, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0808, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1309, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0917, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0881, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0913, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0909, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0893, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0976, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0872, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0541, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0851, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0896, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0685, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0816, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1112, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0779, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0983, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0832, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0807, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0862, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0656, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0908, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0778, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0680, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0772, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0606, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0714, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0846, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0852, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0842, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0704, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0891, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1254, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0729, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0823, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0864, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0870, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0806, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0876, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1192, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1182, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0907, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0956, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0696, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1040, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1002, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1006, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0763, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0656, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0752, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0694, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0851, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0731, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0867, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0773, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0708, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0956, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0919, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0637, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0935, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1280, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0974, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0547, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0721, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0749, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0990, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0950, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0882, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1151, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0875, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0894, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1053, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0817, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0789, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0879, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0767, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0966, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0648, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0924, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0756, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0751, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0831, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0928, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0718, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0703, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1113, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1182, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0963, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0699, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0767, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0775, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0814, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0511, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0711, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0804, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0901, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0816, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0824, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0650, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0826, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1095, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0929, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0606, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0953, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0895, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0974, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0921, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1138, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0826, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1083, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0570, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0943, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1008, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0695, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0907, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0772, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0986, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0936, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0662, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1041, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0847, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0851, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0939, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0713, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0781, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0811, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0729, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0536, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1097, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0658, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0987, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0746, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0899, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1143, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0758, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1004, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0976, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0683, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0770, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0777, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0931, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0859, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0646, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0678, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0806, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0764, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0903, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0879, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1083, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1082, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1139, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0935, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0632, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0547, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0956, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0749, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0662, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0741, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0936, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0687, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0824, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0783, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0632, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1067, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0824, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1060, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0885, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0909, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0948, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1130, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0901, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0889, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0798, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1111, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1121, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0850, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0681, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0775, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0728, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0840, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0997, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0748, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0760, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0810, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0678, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0921, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0979, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0708, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0672, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0958, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0707, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0728, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0790, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1184, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0653, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1109, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0860, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1190, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1182, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0733, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0881, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0614, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0827, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0770, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0896, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0927, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0795, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0781, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0744, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0716, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0806, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0907, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0641, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0815, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0988, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0866, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0814, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0816, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1275, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1038, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1008, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0896, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0901, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0980, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0772, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0883, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1105, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0973, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0965, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0801, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0611, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0933, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0891, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0870, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1077, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0779, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0841, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0940, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0880, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0941, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0759, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0869, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0690, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0751, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1055, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0918, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0884, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0664, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0744, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0759, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0961, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0670, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0892, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0829, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.1080, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0754, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0823, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0883, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0816, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0752, grad_fn=<BinaryCrossEntropyBackward0>)
# LOSS: tensor(0.0905, grad_fn=<BinaryCrossEntropyBackward0>)
# Final F1 score: 0.4832939578343816
# Final MicroAvg F1 score: 0.9665879156687632
